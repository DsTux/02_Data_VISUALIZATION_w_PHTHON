# %% [markdown]
# https://matplotlib.org/gallery/lines_bars_and_markers/barchart.html#sphx-glr-gallery-lines-bars-and-markers-barchart-py

# %% [markdown]
# ### https://matplotlib.org/gallery/

# %%
import matplotlib.pyplot as plt

# %%
age = [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45]
salary = [38496, 42000, 46752, 49320, 53200,
         56000, 62316, 64928, 67317, 68748, 73752]

salary_2 = [45372, 48876, 53850, 57287, 63016,
            65998, 70003, 70000, 71496, 75370, 83640]

# %%
import pandas as pd

# %%
df = pd.DataFrame(list(zip(age, salary, salary_2)), columns =['age', 'salary', 'salary_2'])

# %%
df.head()
# Out:
#    age  salary  salary_2
# 0   25   38496     45372
# 1   27   42000     48876
# 2   29   46752     53850
# 3   31   49320     57287
# 4   33   53200     63016

# %%
fig = plt.figure(figsize=(8,4))

# %%
fig, ax = plt.subplots(figsize=(6,3))
ax.plot(age, salary, 'r')
ax.set_xlabel('age')
ax.set_ylabel('salary')
ax.set_title('title');

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,3))
ax[0].plot(age, salary)
ax[0].set_xlabel('age')
ax[1].plot(age, salary_2)
ax[0].set_title('First')
ax[1].set_title('Second')
ax[1].set_xlabel('age')
plt.tight_layout()

# %% [markdown]
# # saving figures

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10,3))
ax[0].plot(age, salary)
ax[0].set_xlabel('age')
ax[1].plot(age, salary_2)
ax[0].set_title('First')
ax[1].set_title('Second')
ax[1].set_xlabel('age')
plt.tight_layout()

# %%
fig.savefig("myplot.png", dpi= 100)

# %%
pwd # bu directory altina "save" islemi yaptik.
# Out:
# 'C:\\Users\\ilkca\\DATA_SCIENCE\\03_Data_VISUALIZATION_w_PHTHON\\05-Data-Visualization-with-Matplotlib\\Lesson_lab'

# %%
fig.savefig("myplot.pdf")

# %%
fig.savefig("myplot.jpeg")

# %% [markdown]
# # Legends labels and titles

# %%
fig, ax = plt.subplots(figsize=(6,3))
ax.plot(age, salary, label = "salary1")
ax.set_xlabel('age')
ax.plot(age, salary_2, label = "salary2")
ax.set_title('Title')
ax.set_xlabel('age')
ax.set_ylabel('salary')
ax.legend()
plt.tight_layout()

# %% [markdown]
# # setting colors, linewidths, linetypes

# %%
fig, ax = plt.subplots(figsize=(8,4))

#"-","--","-.",":",""

ax.plot(age, salary, color = "red", lw= 5, linestyle="steps");  #'r' or only "r" yada linewidth=5
# Out:
# C:\Users\ilkca\anaconda3\anaconda3\lib\site-packages\ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Passing the drawstyle with the linestyle as a single string is deprecated since Matplotlib 3.1 and support will be removed in 3.3; please pass the drawstyle separately using the drawstyle keyword argument to Line2D or set_drawstyle() method (or ds/set_ds()).
#   """

# %%
fig, ax = plt.subplots(figsize=(8,4))

#"-","--","-.",":",""  alpha degeri saydamlik, transparanlik

ax.plot(age, salary, color = "red", lw= 2, ls="-" , marker= "o",markersize= 8, markerfacecolor="r", alpha=0.2 );  #'r' or only "r" yada linewidth=5 linestyle="-"

# %%
fig, ax = plt.subplots(figsize=(8,4))

ax.plot(age, salary, label="salary_1")
ax.set_xlabel('age')
ax.set_title('Title')
ax.set_ylabel('salary')
ax.legend();

# %%
fig, ax = plt.subplots(figsize=(8,4))
# '-', '--', '-.', ':', ''
ax.plot(age, salary, "r", lw=3, ls = ' ', marker = "o", markersize = 10);

# %%
fig, ax = plt.subplots(figsize=(8,4))
# '-', '--', '-.', ':', ''
ax.plot(age, salary, "b", lw=3, ls = ' ', marker = "o", markersize = 10, markerfacecolor ="r", alpha=0.2);

# %%
# plot range (xlim - ylim)

# %%
fig, ax = plt.subplots(figsize=(8,4))
ax.plot(age, salary)
ax.set_xlim([30,40])   ##### x ve y ekseninde range belirtebiliyoruz grafik cizdirirken 
ax.set_ylim([45000,60000]);

# %% [markdown]
# # adding vertical- horizantal lines

# %%
fig, ax = plt.subplots(figsize=(8,4))

ax.plot(age, salary, color = "red", lw= 3, ls="-" , marker= "o",markersize= 8);  #'r' or only "r" yada linewidth=5 linestyle="-"
ax.axvline(x=35, color = "green", ls="--")
ax.axhline(y=60000, color = "green", ls="--")

# %% [markdown]
# # SPECIAL PLOT TYPES\
#
# # bar plot

# %%
country = ["UK", "USA", "FRA", "GER", "NOR"]
pci = [40000, 50000, 38000, 55000, 80000]

# %%
# pci = sorted(pci)

# %%
fig, ax = plt.subplots()
ax.bar(country, pci)
# Out:
# <BarContainer object of 5 artists>

# %%
import numpy as np

# %%
fig, ax = plt.subplots()
ax.bar([0,1,2,3,4], pci)
# Out:
# <BarContainer object of 5 artists>

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

# %% [markdown]
# https://matplotlib.org/gallery/lines_bars_and_markers/barchart.html#sphx-glr-gallery-lines-bars-and-markers-barchart-py

# %%
fig, ax = plt.subplots()
ax.bar(labels, men_means)
# Out:
# <BarContainer object of 5 artists>

# %%
fig, ax = plt.subplots()
ax.bar(labels, women_means, color= 'orange')
# Out:
# <BarContainer object of 5 artists>

# %%
fig, ax = plt.subplots()
ax.bar(labels, men_means)
ax.bar(labels, women_means, color= 'orange')
# Out:
# <BarContainer object of 5 artists>

# %%
x = np.arange(len(labels)) #label locations.
x
# Out:
# array([0, 1, 2, 3, 4])

# %%
width = 0.35 # the width of the bars

# %%
x-width/2
# Out:
# array([-0.175,  0.825,  1.825,  2.825,  3.825])

# %%
x-width/2
# Out:
# array([-0.175,  0.825,  1.825,  2.825,  3.825])

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots()
ax.bar(x - width/2, men_means, width, label='Men')
ax.bar(x + width/2, women_means, width, label='Women')
# Out:
# <BarContainer object of 5 artists>

# %%
x
# Out:
# array([0, 1, 2, 3, 4])

# %%
labels
# Out:
# ['G1', 'G2', 'G3', 'G4', 'G5']

# %%
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars
fig, ax = plt.subplots()
ax.bar(x - width/2, men_means, width, label='Men')
ax.bar(x + width/2, women_means, width, label='Women')

 
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(9,6))
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
#autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(9,6))
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() , height), ##Burda ki /2 ile coln ustunde sayi yazdirma ayari oluyor
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
#autolabel(rects2)

fig.tight_layout()

plt.show()

# %%
age = [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45]

fig, ax = plt.subplots(figsize=(10,6))

ax.plot(age, salary, color = 'r', lw = 3)

ax.set_xticks([25, 27, 29, 31, 33, 35, 37, 39, 41, 43])
ax.set_xticklabels(labels);
#ax.set_xticklabels(labels*2);

# %%
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

# %%
rects1
# Out:
# <BarContainer object of 5 artists>

# %%
rects1[0]

# %%
print(rects1[0])
# Out:
# Rectangle(xy=(-0.35, 0), width=0.35, height=20, angle=0)

# %%
rects1[0].get_height()
# Out:
# 20

# %%
rects1[0].get_x()
# Out:
# -0.35

# %%
rects1[0].get_width()
# Out:
# 0.35

# %%
for i in rects1:
    print(i)
# Out:
# Rectangle(xy=(-0.35, 0), width=0.35, height=20, angle=0)
# Rectangle(xy=(0.65, 0), width=0.35, height=34, angle=0)
# Rectangle(xy=(1.65, 0), width=0.35, height=30, angle=0)
# Rectangle(xy=(2.65, 0), width=0.35, height=35, angle=0)
# Rectangle(xy=(3.65, 0), width=0.35, height=27, angle=0)

# %%
age = [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45]

fig, ax = plt.subplots(figsize=(8,4))

ax.plot(age, salary, "r", lw=3)
ax.set_xticks([25, 27, 29, 31, 33, 35, 37, 39, 41, 43,])
ax.set_xticklabels(labels*2);

# %% [markdown]
# # to do the same plot with pandas

# %%
import pandas as pd
df = pd.DataFrame(list(zip(labels, men_means, women_means)), columns =["labels", "men", "women"])
df.head()
# Out:
#   labels  men  women
# 0     G1   20     25
# 1     G2   34     32
# 2     G3   30     34
# 3     G4   35     20
# 4     G5   27     25

# %%
df.plot.bar()

# %%
df.plot.bar(figsize=(9,6))

# %%
ax = df.plot.bar(rot= 1, figsize=(9,6))
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.axhline(y=20, color="green", ls="--")

ax.legend()

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.05, p.get_height()+0.5)) # 0.5 kolon tepesine yazilma araligi

# %%
x
# Out:
# array([0, 1, 2, 3, 4])

# %%
ax = df.plot.bar(rot= 45, figsize=(9,6)) # rot=45 ile x ekseninde labellerin yonu 45 derece degisti.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
#ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.axhline(y=20, color ="green", ls="--")
ax.legend()

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.05, p.get_height()+0.5)) # 0.5 kolon tepesine yazilma araligi

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
width = 0.35 # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, label = "Men")
ax.bar(labels, women_means, width, bottom = men_means, label = "Women")

ax.set_ylabel("Scores")
ax.set_title("Scores by group and gender")
ax.legend()

plt.show()

# %%
df.plot.bar("labels", stacked = "True")

# %%
df.plot.barh("labels", stacked = "True", rot=0)

# %%
df.plot(kind="barh", stacked=True)

# %%
 df.plot.bar("labels", stacked = "True", rot=0)

# %%
df.plot(kind="bar", stacked=True,)

# %%
ax = df.plot.bar(rot= 0, figsize=(9,6))
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
#ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.axhline(y=20, color ="green", ls="--")
ax.legend()

for p in ax.patches:
    ax.annotate((p.get_height()), (p.get_x()+0.05, p.get_height()+0.5)) # 0.5 kolon tepesine yazilma araligi

# %%
df[["ilk sütun", "2.sütun"]].plot(kind = "box")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-65-76e51e428637> in <module>
# ----> 1 df[["ilk sütun", "2.sütun"]].plot(kind = "box")
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.DataFrame(np.random.normal(10,1,30).reshape(10,3), index = pd.date_range('2010-01-01', freq = 'M', periods = 10), columns = ('one', 'two', 'three'))
df['key1'] = (4,4,4,6,6,6,8,8,8,8)
fig1 = plt.figure(1)
ax1 = fig1.add_subplot(111)
ax1.scatter(df['one'], df['two'], marker = 'o', c = df['key1'], alpha = 0.8)
plt.show()
