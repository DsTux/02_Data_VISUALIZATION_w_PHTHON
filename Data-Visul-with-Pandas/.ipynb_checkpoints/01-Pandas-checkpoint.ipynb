# %%
##### Pandas ile cizimde index defeoult geliyor bir daha tanimlamiyoruz yoksa hata verir.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv("df1", index_col = 0)
df2 = pd.read_csv("df2")

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df = pd.DataFrame({'sales': [3, 2, 3, 9, 10, 6], 'signups': [5, 5, 6, 12, 14, 13],
                   'visits': [20, 42, 28, 62, 81, 50]},
                  index=pd.date_range(start='2018/01/01', end='2018/07/01',
                                      freq='M'))
df.head()
# Out:
#             sales  signups  visits
# 2018-01-31      3        5      20
# 2018-02-28      2        5      42
# 2018-03-31      3        6      28
# 2018-04-30      9       12      62
# 2018-05-31     10       14      81

# %%
df.shape
# Out:
# (6, 3)

# %%
sns.set_style("darkgrid") ### Grafikteki atrka cizgiler gitti "darkgrid" ile

# %%
df1["A"].hist()

# %%
plt.style.use('bmh')
df1['A'].hist()

# %%
plt.style.use('dark_background')
df1['A'].hist()

# %%
plt.style.use('fivethirtyeight')
df1['A'].hist()

# %%
df1['A'].plot.hist(bins=50)

# %%
plt.style.use('ggplot')

# %%
#1.YONTEM

df.plot.area(figsize = (9,6))  
### Herbirini gormek kasar toplamini da gormek onemli ise bunu kullanmak yararli.
#zaman cizelgen varsa guzel gider.
#aralaridan fark baya varsa guzel olur cizdirmek.

# %%
df2.plot.area(alpha=0.4)

# %%
#2. METHOD
df.plot(kind="area")

# %%
sns.set_style("darkgrid")

# %% [markdown]
# ## BarPLOT

# %%
speed = [0.1, 17.5, 40, 48, 52, 69, 88]
lifespan = [2, 8, 70, 1.5, 25, 12, 28]
index = ['snail', 'pig', 'elephant','rabbit', 'giraffe', 'coyote', 'horse']
df = pd.DataFrame({'speed': speed,'lifespan': lifespan}, index=index)
df.head()
# Out:
#           speed  lifespan
# snail       0.1       2.0
# pig        17.5       8.0
# elephant   40.0      70.0
# rabbit     48.0       1.5
# giraffe    52.0      25.0

# %%
df.plot.bar(figsize=(9,6), rot=45)
plt.axhline(y=50, color="green", ls="--")

# %%
labels = ['Snail', 'Pig', 'Elephant','Rabbit', 'Giraffe', 'Coyote', 'Horse']

# %%
g = df.plot.bar(figsize=(9,6), rot=45)

g.set_xticklabels(labels)

g.set_ylabel('speed/lifespan')

for p in g.patches:
    g.annotate((p.get_height()), (p.get_x()+0.02, p.get_height()+0.5))

# %%
#### FARKLI BIR ORNEK


r = [0,1,2,3,4]
raw_data = {‘greenBars’: [20, 1.5, 7, 10, 5], ‘orangeBars’: [5, 15, 5, 10, 15],‘blueBars’: [2, 15, 18, 5, 10]}
df = pd.DataFrame(raw_data)
totals = [i+j+k for i,j,k in zip(df[‘greenBars’], df[‘orangeBars’], df[‘blueBars’])]
greenBars = [i / j * 100 for i,j in zip(df[‘greenBars’], totals)]
orangeBars = [i / j * 100 for i,j in zip(df[‘orangeBars’], totals)]
blueBars = [i / j * 100 for i,j in zip(df[‘blueBars’], totals)]
barWidth = 0.85
names = (‘A’,‘B’,‘C’,‘D’,‘E’)
plt.bar(r, greenBars, color=‘#B5FFB9’, edgecolor=‘white’, width=barWidth)
plt.bar(r, orangeBars, bottom=greenBars, color=‘#F9BC86’, edgecolor=‘white’, width=barWidth)
plt.bar(r, blueBars, bottom=[i+j for i,j in zip(greenBars, orangeBars)], color=‘#A3ACFF’, edgecolor=‘white’, width=barWidth)
plt.xticks(r, names)
plt.xlabel(“group”)
plt.show()
# Out:
#   File "<ipython-input-112-d9fe1d6a849e>", line 5
#     raw_data = {‘greenBars’: [20, 1.5, 7, 10, 5], ‘orangeBars’: [5, 15, 5, 10, 15],‘blueBars’: [2, 15, 18, 5, 10]}
#                           ^
# SyntaxError: invalid character in identifier

# %%
income = [100, 80, 150, 48, 52, 69, 88]
expense = [30, 100, 100, 20, 75, 50, 28]
index = ['snail', 'pig', 'elephant','rabbit', 'giraffe', 'coyote', 'horse']
df = pd.DataFrame({'income': income,'expense': expense}, index=index)
df.head()
# Out:
#           income  expense
# snail        100       30
# pig           80      100
# elephant     150      100
# rabbit        48       20
# giraffe       52       75

# %%
df.plot.bar(stacked = True) ## bar() defeult u

# %%
profit = [100, 80, 150, 48, 52, 69, 88]

# %%
#df = pd.DataFrame({'income': income,'expense': expense, "profit": df.income - df.expense}, index=index)

# %%
df["profit"] = df.income - df.expense
df.head()
# Out:
#           income  expense  profit
# snail        100       30      70
# pig           80      100     -20
# elephant     150      100      50
# rabbit        48       20      28
# giraffe       52       75     -23

# %%
df.loc["Total"] = df.sum()  # Bir Total eklemek istersek bu kodu kullanabiliriz.
df
# Out:
#           income  expense  profit
# snail        100       30      70
# pig           80      100     -20
# elephant     150      100      50
# rabbit        48       20      28
# giraffe       52       75     -23
# coyote        69       50      19
# horse         88       28      60
# Total        587      403     184

# %%
mpg = sns.load_dataset("mpg")
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.horsepower.plot.hist(bins = 20)

# %%
mpg.horsepower.plot(kind="hist", bins=20)

# %% [markdown]
# ### lineplots

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1["B"].plot(figsize=(10,6))  ### Line plot yapacaksak default cizer belirtmeye gerek yok.

# %%
df1.plot(y = "B", figsize= (10,6))

# %%
df1.plot(x= df1.index, y = "B", figsize= (10,6)) ### HATA VERIR index i tekrar tanimlarsak hata verir.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-126-758ce99fcde0> in <module>
# ----> 1 df1.plot(x= df1.index, y = "B", figsize= (10,6)) ### HATA VERIR index i tekrar tanimlarsak hata verir.
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     810                 if is_integer(x) and not data.columns.holds_integer():
#     811                     x = data_cols[x]
# --> 812                 elif not isinstance(data[x], ABCSeries):
#     813                     raise ValueError("x must be a label or position")
#     814                 data = data.set_index(x)
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# ...

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.groupby("model_year").horsepower.mean().plot()

# %%
mpg.groupby("model_year").mpg.mean().plot(ls = "--")

# %%
mpg.groupby("model_year").horsepower.median().plot()
mpg.groupby("model_year").mpg.mean().plot(secondary_y =True, stylels = "--")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-130-81daf14e3034> in <module>
#       1 mpg.groupby("model_year").horsepower.mean().plot()
# ----> 2 mpg.groupby("model_year").mpg.mean().plot(secondary_y =True, stylels = "--")
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\anaconda3\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ...

# %%
pip install pandas-datareader

# %%
from pandas_datareader import data
from datetime import datetime

start = datetime (2020, 1,1 )
end = datetime(2020, 8, 30)

# %%
f = data.DataReader(name="AAPL", data_source="av-daily", start=start, end=end, api_key = "CI1UUA44YI12JAB3")

# %%
#pip install pandas-datareader
#htttps://www.alphavantages.co/support/#api-key **** to create the API KEY

# %%
f.index=pd.to_datetime(f.index)

# %%
f.close.plot(figsize = (10,7))

# %%
import matplotlib.dates as mdates
import numpy as np
fig, ax = plt.subplots(figsize=(10,7))
#ax.xaxis.set_minor_locator(mdates.DayLocator(interval=1))
ax.set_xticklabels(f.index, rotation=45)
ax.xaxis.set_major_locator(mdates.DayLocator(interval=15))  ### Burada tarihleri kontroledebiliyoruz.
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.plot(f.close.index, f.close);

# %% [markdown]
# ### MOVING Average

# %%
seven = f.close.rolling(window = 7).mean()

# %%
seven.head(10)  ##Ilk 6 gun NAN cunku onlarin ortalamsini alica, 7 gunluk ortalamda.
# Out:
# 2020-01-02           NaN
# 2020-01-03           NaN
# 2020-01-06           NaN
# 2020-01-07           NaN
# 2020-01-08           NaN
# 2020-01-09           NaN
# 2020-01-10    302.731429
# 2020-01-13    305.104286
# 2020-01-14    307.282857
# 2020-01-15    308.931429
# Name: close, dtype: float64

# %%
ten = f.close.rolling(window = 10).mean()

# %%
ten.head(10)
# Out:
# 2020-01-02       NaN
# 2020-01-03       NaN
# 2020-01-06       NaN
# 2020-01-07       NaN
# 2020-01-08       NaN
# 2020-01-09       NaN
# 2020-01-10       NaN
# 2020-01-13       NaN
# 2020-01-14       NaN
# 2020-01-15    306.01
# Name: close, dtype: float64

# %%
df1.B.head()
# Out:
# 2000-01-01   -0.163643
# 2000-01-02    0.137034
# 2000-01-03   -0.482943
# 2000-01-04   -0.072973
# 2000-01-05    1.778576
# Name: B, dtype: float64

# %%
twenty = f.close.rolling(window = 20).mean()

# %%
thirty = f.close.rolling(window = 30).mean()

# %%
plt.figure(figsize =(15,10))
f.close.plot(ls= "-")
seven.plot(ls="--")
ten.plot(ls="-")
twenty.plot(ls=":")
thirty.plot()
plt.legend(["close","seven", "ten", "twenty","thirty"], facecolor = "blue")

# %% [markdown]
# ## Scatterplot()
# C orrelasyonun standartlasmis hali correlation a bakmak icin sctter plot cik anlamli

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.plot.scatter("mpg", "weight")

# %%
mpg.plot.scatter(x="mpg", y="weight", c ="horsepower", cmap="coolwarm") ## pandas in "hue" si gibi 3. bir deger ekledik.

# %% [markdown]
# ## Hoxagonal Bin Plot

# %%
mpg.plot.hexbin("mpg", 'weight', gridsize=20)

# %% [markdown]
# ## Boxplot

# %%
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.weight.plot.box() ## Daha iyiyi kde ile dist gorup violin plot ta gorebiliriz, burada yogunluk net anlasilmiyor.

# %%
sns.boxplot(x="origin",y="mpg",data=mpg)

# %%
sns.boxplot(x="origin",y="horsepower",data=mpg)

# %% [markdown]
# ### kde plot with Histogram

# %%
df=mpg = sns.load_dataset("mpg")
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
sns.boxplot(df["horsepower"], ax=ax_box)
sns.distplot(df["horsepower"], ax=ax_hist)
ax_box.set(xlabel='')
# Out:
# [Text(0.5, 0, '')]

# %%
import warnings
warnings.filterwarnings("ignore")
mpg.boxplot(column ="horsepower", by = "origin");

# %% [markdown]
# ### Kde Plot

# %%
mpg.horsepower.plot.kde()

# %%
mpg.horsepower.plot.density()
